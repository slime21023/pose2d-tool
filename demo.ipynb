# %%
from src.predict import keypoints_with_scores, visualize_keypoints
# Out:
# WARNING:tensorflow:From c:\anaconda\envs\py39\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\anaconda\envs\py39\lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\anaconda\envs\py39\lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\anaconda\envs\py39\lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\anaconda\envs\py39\lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.

# %%
# %%time
points = keypoints_with_scores('resource/p-001.jpg')
points
# Out:
# CPU times: total: 938 ms
# Wall time: 177 ms
# array([[[[0.17698173, 0.36518377, 0.6235413 ],
#          [0.15795052, 0.37385374, 0.521559  ],
#          [0.15558136, 0.35514066, 0.511866  ],
#          [0.14448982, 0.356108  , 0.42301363],
#          [0.13115713, 0.3089011 , 0.5729224 ],
#          [0.2071273 , 0.37576088, 0.610897  ],
#          [0.22760716, 0.22859137, 0.58249325],
#          [0.30370143, 0.4808254 , 0.726416  ],
#          [0.3649832 , 0.20154218, 0.59352964],
#          [0.28965935, 0.5549234 , 0.6825515 ],
#          [0.4290385 , 0.28438705, 0.798337  ],
#          [0.42275095, 0.42618614, 0.68801147],
#          [0.46259993, 0.36251575, 0.7672978 ],
#          [0.3980486 , 0.57686305, 0.7005565 ],
#          [0.649717  , 0.43825957, 0.6663372 ],
#          [0.5417967 , 0.7077638 , 0.59030676],
#          [0.8051039 , 0.3498901 , 0.6046054 ]]]], dtype=float32)

# %%
visualize_keypoints('resource/p-001.jpg')

# %%
visualize_keypoints('resource/p-002.jpg')

# %%
visualize_keypoints('resource/p-003.jpg')

# %%
visualize_keypoints('resource/p-004.jpg')

# %%
from src.ml.movenet import _module as module
print(module)
# Out:
# <tensorflow.python.saved_model.load.Loader._recreate_base_user_object.<locals>._UserObject object at 0x000001A542A0E760>
